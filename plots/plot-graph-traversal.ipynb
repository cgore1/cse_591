# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
# %matplotlib inline

# %%
#citeseerx

x = [0.0001,0.001,0.01,0.1,1]
#with plt.style.context('fivethirtyeight'):
#20%
y = [240,229,154,64,9]
plt.plot(x,y, label='80%', linewidth=1, color='red', marker = '^')


#40
x = [0.0001,0.001,0.01,0.1,1]
y = [226,204,152,47,10]
plt.plot(x,y, label='60%', linewidth=1, color='darkcyan', marker = 'o')


#60
x = [0.0001,0.001,0.01,0.1,1]
y = [210,216,154,63,9]
plt.plot(x,y, label='40%', linewidth=1 , color='green', marker = 'v')

#80
x = [0.0001,0.001,0.01,0.1,1]
y = [214,218,168,139,27]
plt.plot(x,y, label='20%', linewidth=1 , color='blue', marker = 'x')



plt.axis([min(x)/2, max(x) * 2, min(y)/10, max(y) * 5])
plt.legend(loc='lower left')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Query Time (ms)')
plt.xlabel('Spatial Range')
plt.tight_layout()
plt.savefig('C:\\Users\\cHinmaY\\cse_591\\plot1.eps', format='eps', transparent='true', facecolor='white', dpi=1000)
plt.savefig('C:\\Users\\cHinmaY\\cse_591\\plot1.jpeg', format='jpeg', transparent='true', facecolor='white', dpi=1000)
plt.show()

# %%
#go_uniprot

x = [0.0001,0.001,0.01,0.1,1]
#with plt.style.context('fivethirtyeight'):
#20%
y = [44,43,36,22,9]
plt.plot(x,y, label='80%', linewidth=1, color='red', marker = '^')

#40
x = [0.0001,0.001,0.01,0.1,1]
y = [42,39,40,22,10]
plt.plot(x,y, label='60%', linewidth=1, color='darkcyan', marker = 'o')

#60
x = [0.0001,0.001,0.01,0.1,1]
y = [41,46,42,25,11]
plt.plot(x,y, label='40%', linewidth=1, color='green', marker = 'v')

#80
x = [0.0001,0.001,0.01,0.1,1]
y = [43,41,39,35,16]
plt.plot(x,y, label='20%', linewidth=1, color='blue', marker = 'x')

plt.axis([min(x)/2, max(x) * 2, min(y)/2, max(y) * 2])
plt.legend(loc='lower left')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Query Time (ms)')
plt.xlabel('Spatial Range')
plt.tight_layout()
plt.savefig('C:\\Users\\cHinmaY\\cse_591\\plot2.eps', format='eps', transparent='true', facecolor='white', dpi=1000)
plt.savefig('C:\\Users\\cHinmaY\\cse_591\\plot2.jpeg', format='jpeg', transparent='true', facecolor='white', dpi=1000)
plt.show()

# %%
#patents

x = [0.0001,0.001,0.01,0.1,1]
#with plt.style.context('fivethirtyeight'):
#20%
y = [3039,322,61,17,10]
plt.plot(x,y, label='80%', linewidth=1, color='red', marker = '^')

#40
x = [0.0001,0.001,0.01,0.1,1]
y = [1969,415,85,19,10]
plt.plot(x,y, label='60%', linewidth=1, color='darkcyan', marker = 'o')

#60
x = [0.0001,0.001,0.01,0.1,1]
y = [2155,663,110,24,11]
plt.plot(x,y, label='40%', linewidth=1, color='green', marker = 'v')

#80
x = [0.0001,0.001,0.01,0.1,1]
y = [2885,1068,183,40,12]
plt.plot(x,y, label='20%', linewidth=1, color='blue', marker = 'x')


plt.axis([min(x)/2, max(x) * 2, min(y)/2, max(y) * 5])
plt.legend(loc='lower left')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Query Time (ms)')
plt.xlabel('Spatial Range')
plt.tight_layout()
plt.savefig('C:\\Users\\cHinmaY\\cse_591\\plot3.eps', format='eps', transparent='true', facecolor='white', dpi=1000)
plt.savefig('C:\\Users\\cHinmaY\\cse_591\\plot3.jpeg', format='jpeg', transparent='true', facecolor='white', dpi=1000)
plt.show()

# %%
#uniprotenc_150m

x = [0.0001,0.001,0.01,0.1,1]
#with plt.style.context('fivethirtyeight'):
#20%
y = [25,13,13,14,10]
plt.plot(x,y, label='80%', linewidth=1, color='red', marker = '^')


#40
x =[0.0001,0.001,0.01,0.1,1]
y = [13,13,13,13,10]
plt.plot(x,y, label='60%', linewidth=1, color='darkcyan', marker = 'o')


#60
x = [0.0001,0.001,0.01,0.1,1]
y = [13,13,14,13,10]
plt.plot(x,y, label='40%', linewidth=1, color='green', marker = 'v')


#80
x = [0.0001,0.001,0.01,0.1,1]
y = [13,13,12,13,13]
plt.plot(x,y, label='20%', linewidth=1, color='blue', marker = 'x')

plt.axis([min(x)/2, max(x) * 2 , min(y)/2, max(y) * 30])
plt.legend(loc='lower left')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Query Time (ms)')
plt.xlabel('Spatial Range')
plt.tight_layout()
plt.savefig('C:\\Users\\cHinmaY\\cse_591\\plot4.eps', format='eps', transparent='true', facecolor='white', dpi=1000)
plt.savefig('C:\\Users\\cHinmaY\\cse_591\\plot4.jpeg', format='jpeg', transparent='true', facecolor='white', dpi=1000)
plt.show()

# %%
plt.style.available
# Out:
# [u'dark_background', u'bmh', u'grayscale', u'ggplot', u'fivethirtyeight']

# %%
plt.subplots()
# Out:
# (<matplotlib.figure.Figure at 0xcd75c18>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xcd75fd0>)
