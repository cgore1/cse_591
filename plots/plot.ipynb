# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
# %matplotlib inline

# %%
#citeseerx

x = [0.0001,0.001,0.01,0.1,1]
with plt.style.context('fivethirtyeight'):
    #20%
    y = [1441,1953,6962,54909,323874]
    plt.plot(x,y, label='80%', linewidth=1, color='red')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)


    #40
    x = [0.0001,0.001,0.01,0.1]
    y = [1333,1706,5411,41173]
    plt.plot(x,y, label='60%', linewidth=1, color='darkcyan')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)

    #60
    x = [0.0001,0.001,0.01,0.1]
    y = [1228,1480,3797,26930]
    plt.plot(x,y, label='40%', linewidth=1 , color='green')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)

    #80
    x = [0.0001,0.001,0.01,0.1]
    y = [1070,1330,2335,13934]
    plt.plot(x,y, label='20%', linewidth=1 , color='blue')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)


    plt.axis([min(x)/2, max(x) * 10 + 1, min(y)/10, max(y) * 30])
    plt.legend(loc='upper left', shadow=True)
    plt.xscale('log')
    plt.yscale('log')
    plt.ylabel('Query Time (ms)')
    plt.xlabel('Spatial Range')
    plt.show()

# %%
#go_uniprot

x = [0.0001,0.001,0.01,0.1]
with plt.style.context('fivethirtyeight'):
    #20%
    y = [2302,1950,3684,8047]
    plt.plot(x,y, label='80%', linewidth=1, color='red')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)


    #40
    x = [0.0001,0.001,0.01,0.1]
    y = [2244,1893,3014,8405]
    plt.plot(x,y, label='60%', linewidth=1, color='darkcyan')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)

    #60
    x = [0.0001,0.001,0.01,0.1]
    y = [2106,1916,2438,7151]
    plt.plot(x,y, label='40%', linewidth=1, color='green')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)

    #80
    x = [0.0001,0.001,0.01,0.1]
    y = [1704,1891,1856,6233]
    plt.plot(x,y, label='20%', linewidth=1, color='blue')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)


    plt.axis([min(x)/2, max(x) * 10 + 1, min(y)/10, max(y) * 30])
    plt.legend(loc='upper left', shadow=True)
    plt.xscale('log')
    plt.yscale('log')
    plt.ylabel('Query Time (ms)')
    plt.xlabel('Spatial Range')
    plt.show()

# %%
#patents

x = [0.0001,0.001,0.01,0.1]
with plt.style.context('fivethirtyeight'):
    #20%
    y = [1378,1948,4846,26283]
    plt.plot(x,y, label='80%', linewidth=1, color='red')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)


    #40
    x = [0.0001,0.001,0.01,0.1]
    y = [1246,1798,3867,18721]
    plt.plot(x,y, label='60%', linewidth=1, color='darkcyan')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)

    #60
    x = [0.0001,0.001,0.01,0.1]
    y = [1061,1606,3064,13752]
    plt.plot(x,y, label='40%', linewidth=1, color='green')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)

    #80
    x = [0.0001,0.001,0.01,0.1]
    y = [814,1385,2126,7549]
    plt.plot(x,y, label='20%', linewidth=1, color='blue')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)


    plt.axis([min(x)/2, max(x) * 10 + 1, min(y)/10, max(y) * 30])
    plt.legend(loc='upper left', shadow=True)
    plt.xscale('log')
    plt.yscale('log')
    plt.ylabel('Query Time (ms)')
    plt.xlabel('Spatial Range')
    plt.show()

# %%
#uniprotenc_150m

x = [0.0001,0.001,0.01,0.1,1]
with plt.style.context('fivethirtyeight'):
    #20%
    y = [5119,5628,19295,612761,310301]
    plt.plot(x,y, label='80%', linewidth=1, color='red')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)


    #40
    x = [0.0001,0.001,0.01]
    y = [4785,5757,22076]
    plt.plot(x,y, label='60%', linewidth=1, color='darkcyan')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)

    #60
    x = [0.0001]
    y = [11261]
    plt.plot(x,y, label='40%', linewidth=1, color='green')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)

    #80
    x = [0.0001,0.001,0.01,0.1]
    y = [4746,4307,5919,35719]
    plt.plot(x,y, label='20%', linewidth=1, color='blue')
    for i in range(0, len(y)):
        plt.plot(x[i],y[i], 'kx', markersize = 5)


    plt.axis([min(x)/2, max(x) * 10 + 1, min(y)/10, max(y) * 30])
    plt.legend(loc='upper left', shadow=True)
    plt.xscale('log')
    plt.yscale('log')
    plt.ylabel('Query Time (ms)')
    plt.xlabel('Spatial Range')
    plt.show()
